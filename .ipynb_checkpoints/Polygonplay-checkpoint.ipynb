# %%
# %matplotlib notebook
import pandas, math, itertools
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
from shapely.geometry import Polygon,Point

# %% [markdown]
# Building the discrete grid

# %%
delta = 5
a = np.arange(.5,491,delta)
b = np.arange(.5,680,delta)
c = np.arange(.5,281,delta)
grid = itertools.product(a,b,c)

# %% [markdown]
# Now load polygons from files

# %%
file_names = range(26, 167)
polygons = {}
for f in file_names:
    vertices = pandas.read_csv('parsed_data/sp4/{}.dat'.format(f), names=['x','y','z']).as_matrix()
    polygons[f] = Polygon(vertices)

# %%
flags = np.zeros((len(a)*len(b)*len(c),1))
plot_points = []
i = 0
for pt in grid:
    z = round(pt[2]) 
    if i%10000 == 0:
        print i,'/', len(a)*len(b)*len(c)
    if z in polygons.keys():
        if polygons[z].contains(Point(pt[0], pt[1], pt[2])):
            flags[i] = 1
            plot_points.append(pt)
    i+=1
# Out:
# 0 / 767448
# 10000 / 767448
# 20000 / 767448
# 30000 / 767448
# 40000 / 767448
# 50000 / 767448
# 60000 / 767448
# 70000 / 767448
# 80000 / 767448
# 90000 / 767448
# 100000 / 767448
# 110000 / 767448
# 120000 / 767448
# 130000 / 767448
# 140000 / 767448
# 150000 / 767448
# 160000 / 767448
# 170000 / 767448
# 180000 / 767448
# 190000 / 767448
# 200000 / 767448
# 210000 / 767448
# 220000 / 767448
# 230000 / 767448
# 240000 / 767448
# 250000 / 767448
# 260000 / 767448
# 270000 / 767448
# 280000 / 767448
# 290000 / 767448
# 300000 / 767448
# 310000 / 767448
# 320000 / 767448
# 330000 / 767448
# 340000 / 767448
# 350000 / 767448
# 360000 / 767448
# 370000 / 767448
# 380000 / 767448
# 390000 / 767448
# 400000 / 767448
# 410000 / 767448
# 420000 / 767448
# 430000 / 767448
# 440000 / 767448
# 450000 / 767448
# 460000 / 767448
# 470000 / 767448
# 480000 / 767448
# 490000 / 767448
# 500000 / 767448
# 510000 / 767448
# 520000 / 767448
# 530000 / 767448
# 540000 / 767448
# 550000 / 767448
# ...

# %%
#with open('b1_output.dat', 'w') as f:
#    for flag in flags:
#        f.write('{}\n'.format(flag))

# %%
print sum(flags)
# Out:
# [ 3580.]

# %%
fig = plt.figure(); ax = fig.add_subplot(111, projection='3d')
x = [p[0] for p in plot_points]
y = [p[1] for p in plot_points]
z = [p[2] for p in plot_points]
ax.scatter(x,y,z)
# Out:
# <img src="data:image/png;base64,...">
